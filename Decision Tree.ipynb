# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model  import Ridge,Lasso,RidgeCV, LassoCV, ElasticNet, ElasticNetCV, LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data= pd.read_excel('Printing parameters, melt pool geometry and density of IN625 test coupons.xlsx')
data.head()
# Out:
#    Spec  Power  Speed  Hatching  Energy density  Build rate  \
# 0     1    160    2.8     0.092            15.6        37.0
# 1     2    160    2.8     0.061            23.3        24.7
# 2     3    160    2.8     0.052            27.4        21.0
# 3     4    160    2.8     0.046            31.1        18.5
# 4     5    160    2.8     0.037            38.9        14.8
#
#    Diameter to thickness  Width to height  length to width  Density
# 0                    1.0             1.00              5.7     78.3
# 1                    1.0             1.50              5.7     87.6
# 2                    1.0             1.76              5.7     91.6
# 3                    1.0             2.00              5.7     95.6
# 4                    1.0             2.50              5.7     95.6

# %%
data.plot(kind='scatter', x='Power', y='Density')
data.plot(kind='scatter', x='Speed', y='Density')
data.plot(kind='scatter', x='Hatching', y='Density')
data.plot(kind='scatter', x='Energy density', y='Density')
data.plot(kind='scatter', x='Build rate', y='Density')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
sns.pairplot(data)

# %%
x=data[['Power','Speed','Hatching','Energy density','Build rate']]
y=data[['Density']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state=35)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtree = DecisionTreeRegressor()

# %%
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtree.score(x_train,y_train)
# Out:
# 1.0

# %%
dtree.score(x_test,y_test)
# Out:
# 0.9091289386681058

# %%
prediction=dtree.predict(x_test)

# %%
from sklearn import metrics

# %%
MAE=metrics.mean_absolute_error(y_test, prediction)
MSE=metrics.mean_squared_error(y_test,prediction)
RMSE=np.sqrt(MSE)

# %%
MAE
# Out:
# 0.2785714285714249

# %%
MSE
# Out:
# 0.3435714285714294

# %%
RMSE
# Out:
# 0.5861496639693905

# %%
prediction=dtree.predict(x)

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
plt.scatter(y,prediction)

# %%
#Diameter to thickness

# %%
data.plot(kind='scatter', x='Power', y='Density')
data.plot(kind='scatter', x='Speed', y='Density')
data.plot(kind='scatter', x='Hatching', y='Density')
data.plot(kind='scatter', x='Energy density', y='Density')
data.plot(kind='scatter', x='Build rate', y='Density')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
sns.pairplot(data)

# %%
x=data[['Power','Speed','Hatching','Energy density','Build rate']]
y=data[['Diameter to thickness']]
z=data[['Width to height']]
a=data[['length to width']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state=30)

# %%
dtree = DecisionTreeRegressor()

# %%
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtree.score(x_train,y_train)
# Out:
# 1.0

# %%
dtree.score(x_test,y_test)
# Out:
# 1.0

# %%
prediction=dtree.predict(x_test)

# %%
from sklearn import metrics

# %%
MAE=metrics.mean_absolute_error(y_test, prediction)
MSE=metrics.mean_squared_error(y_test,prediction)
RMSE=np.sqrt(MSE)

# %%
MAE
# Out:
# 0.0

# %%
MSE
# Out:
# 0.0

# %%
RMSE
# Out:
# 0.0

# %%
prediction=dtree.predict(x)

# %%
plt.scatter(y,prediction)

# %%
#Width to height

# %%
x_train,x_test,z_train,z_test = train_test_split(x,z,test_size = 0.25,random_state=35)

# %%
dtree = DecisionTreeRegressor()

# %%
dtree.fit(x_train,z_train)
# Out:
# DecisionTreeRegressor()

# %%
dtree.score(x_train,z_train)
# Out:
# 1.0

# %%
dtree.score(x_test,z_test)
# Out:
# 0.7915083997511185

# %%
from sklearn import metrics

# %%
prediction=dtree.predict(x_test)

# %%
MAE=metrics.mean_absolute_error(z_test, prediction)
MSE=metrics.mean_squared_error(z_test,prediction)
RMSE=np.sqrt(MSE)

# %%
MAE
# Out:
# 0.22666666666666666

# %%
MSE
# Out:
# 0.09773333333333334

# %%
RMSE
# Out:
# 0.3126233090051561

# %%
prediction=dtree.predict(x)

# %%
plt.scatter(z,prediction)

# %%
#length to width

# %%
x_train,x_test,a_train,a_test = train_test_split(x,a,test_size = 0.25,random_state=35)

# %%
dtree = DecisionTreeRegressor()

# %%
dtree.fit(x_train,a_train)
# Out:
# DecisionTreeRegressor()

# %%
dtree.score(x_train,a_train)
# Out:
# 1.0

# %%
dtree.score(x_test,a_test)
# Out:
# 1.0

# %%
prediction=dtree.predict(x)

# %%
plt.scatter(a,prediction)

# %%
# Prediction of density using d/t,w/h,l/w

# %%
data.head()
# Out:
#    Spec  Power  Speed  Hatching  Energy density  Build rate  \
# 0     1    160    2.8     0.092            15.6        37.0
# 1     2    160    2.8     0.061            23.3        24.7
# 2     3    160    2.8     0.052            27.4        21.0
# 3     4    160    2.8     0.046            31.1        18.5
# 4     5    160    2.8     0.037            38.9        14.8
#
#    Diameter to thickness  Width to height  length to width  Density
# 0                    1.0             1.00              5.7     78.3
# 1                    1.0             1.50              5.7     87.6
# 2                    1.0             1.76              5.7     91.6
# 3                    1.0             2.00              5.7     95.6
# 4                    1.0             2.50              5.7     95.6

# %%
x=data[['Diameter to thickness','Width to height','length to width']]
y=data[['Density']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state=35)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtree = DecisionTreeRegressor()

# %%
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtree.score(x_train,y_train)
# Out:
# 1.0

# %%
dtree.score(x_test,y_test)
# Out:
# 0.7009378584440988

# %%
prediction=dtree.predict(x_test)

# %%
from sklearn import metrics

# %%
MAE=metrics.mean_absolute_error(y_test,prediction)
MSE=metrics.mean_squared_error(y_test,prediction)
RMSE=np.sqrt(MSE)

# %%
MAE
# Out:
# 0.43571428571428533

# %%
RMSE
# Out:
# 1.0633504999360694

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
x=data[['Power','Speed','Hatching','Energy density','Build rate']]
y=data[['Density']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

# %%
rfc = RandomForestRegressor(n_estimators=100)
rfc.fit(x_train, y_train)
# Out:
# <ipython-input-326-003eead8d949>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc.fit(x_train, y_train)
# RandomForestRegressor()

# %%
rfc.score(x_train,y_train)
# Out:
# 0.9702795306585195

# %%
rfc.score(x_test,y_test)
# Out:
# 0.9099165825981691

# %%
from sklearn import metrics

# %%
prediction=dtree.predict(x_test)

# %%
MAE=metrics.mean_absolute_error(y_test, prediction)
MSE=metrics.mean_squared_error(y_test,prediction)
RMSE=np.sqrt(MSE)

# %%
MAE
# Out:
# 3.045183153257572e-15

# %%
MSE
# Out:
# 4.3274655372124074e-29

# %%
RMSE
# Out:
# 6.578347465140776e-15

# %%
#Diameter to thickness

# %%
x=data[['Power','Speed','Hatching','Energy density','Build rate']]
y=data[['Diameter to thickness']]
z=data[['Width to height']]
a=data[['length to width']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state=35)

# %%
rfc = RandomForestRegressor(n_estimators=100)
rfc.fit(x_train, y_train)
# Out:
# <ipython-input-118-003eead8d949>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc.fit(x_train, y_train)
# RandomForestRegressor()

# %%
rfc.score(x_train,y_train)
# Out:
# 0.9995536325409203

# %%
rfc.score(x_test,y_test)
# Out:
# 0.9986404699862605

# %%
#Width to height

# %%
x_train,x_test,z_train,z_test = train_test_split(x,z,test_size = 0.25,random_state=35)

# %%
rfc = RandomForestRegressor(n_estimators=100)
rfc.fit(x_train, z_train)
# Out:
# <ipython-input-123-654b055cfcc9>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc.fit(x_train, z_train)
# RandomForestRegressor()

# %%
rfc.score(x_train,z_train)
# Out:
# 0.9857283469452006

# %%
rfc.score(x_test,z_test)
# Out:
# 0.8367837444816449

# %%
#length to width

# %%
x_train,x_test,a_train,a_test = train_test_split(x,a,test_size = 0.25,random_state=35)

# %%
rfc = RandomForestRegressor(n_estimators=100)
rfc.fit(x_train, a_train)
# Out:
# <ipython-input-128-a41d9a5d1a64>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc.fit(x_train, a_train)
# RandomForestRegressor()

# %%
rfc.score(x_train,a_train)
# Out:
# 0.9995654085257549

# %%
rfc.score(x_test,a_test)
# Out:
# 0.9989196695173214

# %%
data.head()
# Out:
#    Spec  Power  Speed  Hatching  Energy density  Build rate  \
# 0     1    160    2.8     0.092            15.6        37.0
# 1     2    160    2.8     0.061            23.3        24.7
# 2     3    160    2.8     0.052            27.4        21.0
# 3     4    160    2.8     0.046            31.1        18.5
# 4     5    160    2.8     0.037            38.9        14.8
#
#    Diameter to thickness  Width to height  length to width  Density
# 0                    1.0             1.00              5.7     78.3
# 1                    1.0             1.50              5.7     87.6
# 2                    1.0             1.76              5.7     91.6
# 3                    1.0             2.00              5.7     95.6
# 4                    1.0             2.50              5.7     95.6

# %%
x=data[['Diameter to thickness','Width to height','length to width']]
y=data[['Density']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,a,test_size = 0.25,random_state=35)

# %%
rfc = RandomForestRegressor(n_estimators=100)
rfc.fit(x_train, y_train)
# Out:
# <ipython-input-88-003eead8d949>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc.fit(x_train, y_train)
# RandomForestRegressor()

# %%
rfc.score(x_train,y_train)
# Out:
# 0.9999226909413854

# %%
rfc.score(x_test,y_test)
# Out:
# 0.9997956225539932

# %%
prediction=dtree.predict(x_test)

# %%
MAE=metrics.mean_absolute_error(y_test, prediction)
MSE=metrics.mean_squared_error(y_test,prediction)
RMSE=np.sqrt(MSE)

# %%
MAE
# Out:
# 93.25

# %%
MSE
# Out:
# 8703.928333333333

# %%
RMSE
# Out:
# 93.2948462313612
